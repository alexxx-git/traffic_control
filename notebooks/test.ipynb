# %%
import json
with open("../configs/zones.json", "r") as file:
    raw_data_zones=json.load(file)
zones_info={key: [int(value) for value in values] for key, values in raw_data_zones["roi_count_road"].items()}
print(zones_info)
# Out:
# {'show': [250, 600, 720, 850], 'detection': [250, 600, 720, 850]}
