# %%
import json
with open("../configs/zones.json", "r") as file:
    raw_data_zones=json.load(file)
zones_info={key: [int(value) for value in values] for key, values in raw_data_zones["main_road"].items()}
print(zones_info)
# Out:
# {'1': [460, 770, 600, 700, 720, 760, 630, 840], '2': [300, 700, 430, 650, 560, 700, 430, 750]}

# %%
from ultralytics import YOLO
rr=YOLO("yolo11s.pt")
