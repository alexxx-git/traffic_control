# %%
import json
import numpy as np
with open("../configs/zones.json", "r") as file:
    raw_data_zones=json.load(file)
    zones = {
        name: {"points": np.array(data["points"], dtype=np.int32), "color": tuple(data["color"])}
        for name, data in raw_data_zones.items()
    }
    print(zones)
# Out:
# {'0': {'points': array([[221, 657],
#        [367, 601],
#        [452, 640],
#        [341, 706]], dtype=int32), 'color': (0, 255, 0)}, '1': {'points': array([[391, 731],
#        [511, 659],
#        [612, 697],
#        [509, 784]], dtype=int32), 'color': (0, 0, 255)}}

# %%
for key in raw_data_zones.keys():
    print(key)
# Out:
# 0
# 1

# %%
from ultralytics import YOLO
rr=YOLO("yolo11s.pt")
